# %% [markdown]
# 1

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 2

# %%
df = pd.read_csv('https://github.com/Jigsaw-Academy-of-Education/AIAcademyBatchB/raw/main/Programming%20in%20Python/Data%20Manipulation%20with%20Python/Fd%20(1).csv')

# %% [markdown]
# 4

# %%
df.head(25)
# Out:
#    FlightDate UniqueCarrier  AirlineID Carrier TailNum  FlightNum  \
# 0   01-Jan-14            DL      19790      DL  N948DN        335
# 1   01-Jan-14            DL      19790      DL  N925DN       1095
# 2   01-Jan-14            DL      19790      DL  N921DN       2422
# 3   01-Jan-14            DL      19790      DL  N937DN       1607
# 4   01-Jan-14            US      20355      US  N668AW        657
# 5   01-Jan-14            US      20355      US  N128UW        894
# 6   01-Jan-14            US      20355      US  N150UW       1843
# 7   01-Jan-14            US      20355      US  N712US       2041
# 8   01-Jan-14            US      20355      US  N602AW        413
# 9   01-Jan-14            DL      19790      DL  N344NB       2030
# 10  01-Jan-14            DL      19790      DL  N318NB       1688
# 11  01-Jan-14            FL      20437      FL  N284AT        652
# 12  01-Jan-14            FL      20437      FL  N285AT       1097
# ...

# %% [markdown]
# 5

# %%
df.tail(10)
# Out:
#       FlightDate UniqueCarrier  AirlineID Carrier TailNum  FlightNum  \
# 30433  15-Mar-14            US      20355      US  N816AW        478
# 30434  15-Mar-14            AA      19805      AA  N3EMAA        240
# 30435  15-Mar-14            AS      19930      AS  N594AS          6
# 30436  15-Mar-14            MQ      20398      MQ  N823MQ       3621
# 30437  15-Mar-14            MQ      20398      MQ  N829MQ       3370
# 30438  15-Mar-14            MQ      20398      MQ  N843MQ       3386
# 30439  15-Mar-14            MQ      20398      MQ  N509MQ       3425
# 30440  15-Mar-14            US      20355      US  N802AW        498
# 30441  15-Mar-14            US      20355      US  N534UW        595
# 30442  15-Mar-14            US      20355      US  N813AW        680
#
#        OriginAirportID  OriginAirportSeqID  OriginCityMarketID Origin  ...  \
# 30433            12889             1288903               32211    LAS  ...
# ...

# %% [markdown]
# 6

# %%
df.shape[0]
# Out:
# 30443

# %% [markdown]
# 7

# %%
df.shape[1]
# Out:
# 25

# %% [markdown]
# 8

# %%
df.columns
# Out:
# Index(['FlightDate', 'UniqueCarrier', 'AirlineID', 'Carrier', 'TailNum',
#        'FlightNum', 'OriginAirportID', 'OriginAirportSeqID',
#        'OriginCityMarketID', 'Origin', 'OriginCityName', 'OriginState',
#        'OriginStateFips', 'OriginStateName', 'OriginWac', 'DestAirportID',
#        'DestAirportSeqID', 'DestCityMarketID', 'Dest', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'CRSDepTime'],
#       dtype='object')

# %% [markdown]
# 9

# %%
df.index
# Out:
# RangeIndex(start=0, stop=30443, step=1)

# %% [markdown]
# 10

# %%
df.dtypes
# Out:
# FlightDate            object
# UniqueCarrier         object
# AirlineID              int64
# Carrier               object
# TailNum               object
# FlightNum              int64
# OriginAirportID        int64
# OriginAirportSeqID     int64
# OriginCityMarketID     int64
# Origin                object
# OriginCityName        object
# OriginState           object
# OriginStateFips        int64
# OriginStateName       object
# OriginWac              int64
# DestAirportID          int64
# DestAirportSeqID       int64
# DestCityMarketID       int64
# Dest                  object
# DestCityName          object
# DestState             object
# DestStateFips          int64
# DestStateName         object
# DestWac                int64
# CRSDepTime             int64
# dtype: object

# %% [markdown]
# 11

# %%
df.OriginCityName
# Out:
# 0        Charlotte, NC
# 1        Charlotte, NC
# 2        Charlotte, NC
# 3        Charlotte, NC
# 4        Charlotte, NC
#              ...
# 30438     New York, NY
# 30439     New York, NY
# 30440      Phoenix, AZ
# 30441      Phoenix, AZ
# 30442      Phoenix, AZ
# Name: OriginCityName, Length: 30443, dtype: object

# %% [markdown]
# 12

# %%
df.OriginCityName.unique()
# Out:
# array(['Charlotte, NC', 'Chicago, IL', 'Denver, CO', 'Houston, TX',
#        'Las Vegas, NV', 'Los Angeles, CA', 'New York, NY', 'Phoenix, AZ',
#        'Washington, DC', 'Atlanta, GA'], dtype=object)

# %%
len(df.OriginCityName.unique())
# Out:
# 10

# %% [markdown]
# 13

# %%
df.OriginCityName.value_counts()
# Out:
# Los Angeles, CA    5323
# Las Vegas, NV      4188
# Atlanta, GA        4091
# Phoenix, AZ        3957
# Denver, CO         3001
# New York, NY       2794
# Charlotte, NC      2408
# Washington, DC     2105
# Houston, TX        1373
# Chicago, IL        1203
# Name: OriginCityName, dtype: int64

# %% [markdown]
# 14

# %%
df.describe()
# Out:
#           AirlineID     FlightNum  OriginAirportID  OriginAirportSeqID  \
# count  30443.000000  30443.000000     30443.000000        3.044300e+04
# mean   20004.716914   1452.611438     12243.582531        1.224361e+06
# std      423.137771   1344.397541      1161.594132        1.161589e+05
# min    19393.000000      1.000000     10397.000000        1.039705e+06
# 25%    19790.000000    475.000000     11278.000000        1.127802e+06
# 50%    19977.000000    927.000000     12478.000000        1.247802e+06
# 75%    20355.000000   2027.000000     12892.000000        1.289203e+06
# max    21171.000000   6536.000000     14107.000000        1.410702e+06
#
#        OriginCityMarketID  OriginStateFips     OriginWac  DestAirportID  \
# count        30443.000000     30443.000000  30443.000000   30443.000000
# mean         31303.321125        21.100516     63.237427   12150.603948
# std            854.842119        15.982840     25.963228    1181.675375
# ...

# %% [markdown]
# 15

# %%
df.describe(include='all')
# Out:
#        FlightDate UniqueCarrier     AirlineID Carrier TailNum     FlightNum  \
# count       30443         30443  30443.000000   30443   30017  30443.000000
# unique         74            13           NaN      13    2815           NaN
# top     12-Feb-14            DL           NaN      DL  N544UW           NaN
# freq          583          6907           NaN    6907      79           NaN
# mean          NaN           NaN  20004.716914     NaN     NaN   1452.611438
# std           NaN           NaN    423.137771     NaN     NaN   1344.397541
# min           NaN           NaN  19393.000000     NaN     NaN      1.000000
# 25%           NaN           NaN  19790.000000     NaN     NaN    475.000000
# 50%           NaN           NaN  19977.000000     NaN     NaN    927.000000
# 75%           NaN           NaN  20355.000000     NaN     NaN   2027.000000
# max           NaN           NaN  21171.000000     NaN     NaN   6536.000000
#
# ...
